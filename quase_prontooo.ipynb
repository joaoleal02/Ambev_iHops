# %%
import pandas as pd
import datetime
empdata = pd.read_csv(r'tabela_ambev_sql_finale.csv',index_col=False, delimiter=';')
empdata['Doc. Date'] = pd.to_datetime(empdata['Doc. Date'], format='%d/%m/%Y')
dados = empdata.loc[empdata['Postal Code'] == 83630]
#print(dados.head())
teste_tabela = empdata.loc[empdata['Subrand'] == 'BUD']
#teste_tabela =  empdata.loc[empdata['Unidade Container'] != 1]
#teste_tabela = teste_tabela.loc[teste_tabela['Unidade Container'] == 1]
#teste_tabela = teste_tabela.loc[teste_tabela['Subrand'] == 'CORONA EXTRA']
teste_tabela
# Out:
#        Doc. Date  Order qty  PCS delivered  HL delivered    MACO/HL   \
# 10    2021-01-11       70.0           70.0        4.2000  127.984305
# 16    2021-01-11       40.0           40.0        2.4000  127.984305
# 51    2021-01-12       20.0           20.0        1.2000  127.984305
# 55    2021-01-12        1.0           72.0        5.7024  102.054025
# 63    2021-01-13      140.0          140.0        8.4000  127.984305
# ...          ...        ...            ...           ...         ...
# 23243 2019-11-22        3.0          210.0       12.6000  127.984305
# 23251 2019-11-22        9.0          630.0       37.8000  127.984305
# 23259 2019-11-27        1.0           70.0        4.2000  127.984305
# 23261 2019-11-27        4.0          280.0       16.8000  127.984305
# 23268 2019-11-28        5.0          350.0       21.0000  127.984305
#
#        Postal Code                        Sous groupement Subrand  \
# 10           83630                         OLIVIER FRERES     BUD
# 16           85700                    VINS REMY LIBOUREAU     BUD
# 51           83130  DISTRIBUTION vins boissons (La Garde)     BUD
# 55           35530                        France BOISSONS     BUD
# 63           42150                        ROUCHON SOUCHON     BUD
# ...            ...                                    ...     ...
# 23243        53200                               VINOBEER     BUD
# 23251        53200                               VINOBEER     BUD
# 23259        26300                               MY BEERS     BUD
# 23261        53200                               VINOBEER     BUD
# 23268        53200                               VINOBEER     BUD
#
#               Container Type  Unidade Container  Container Size  Latitude  \
# 10             PERFECT DRAFT                  1            6.00   43.7330
# 16             PERFECT DRAFT                  1            6.00   46.8354
# 51             PERFECT DRAFT                  1            6.00   43.1228
# 55     BOTTLE VP - Tendances                 24            0.33   48.1211
# 63             PERFECT DRAFT                  1            6.00   45.4168
# ...                      ...                ...             ...       ...
# 23243          PERFECT DRAFT                  1            6.00   47.7993
# 23251          PERFECT DRAFT                  1            6.00   47.7993
# 23259          PERFECT DRAFT                  1            6.00   44.9975
# 23261          PERFECT DRAFT                  1            6.00   47.7993
# 23268          PERFECT DRAFT                  1            6.00   47.7993
#
#        Longitude        TTC   Preço/L  Container Size 2
# 10        6.1765  15.774775  2.629129              6.00
# 16       -0.7778  15.774775  2.629129              6.00
# 51        6.0075  15.774775  2.629129              6.00
# 55       -1.4597  24.491347  3.092342              7.92
# 63        4.3120  16.272216  2.712036              6.00
# ...          ...        ...       ...               ...
# 23243    -0.7210  16.019280  2.669880              6.00
# 23251    -0.7210  16.019280  2.669880              6.00
# 23259     5.1859  16.609464  2.768244              6.00
# 23261    -0.7210  16.019280  2.669880              6.00
# 23268    -0.7210  16.019280  2.669880              6.00
#
# [1442 rows x 16 columns]

# %%
#beer_user = dados.iloc[5]['Subrand']
quantidade_comprada = (dados.iloc[0]['HL delivered'])*100
taxa_recomendacao = 0.1
quantidade_recomendada = quantidade_comprada * taxa_recomendacao 
beer_user = 'CORONA EXTRA'
# consertar LEFFE RITUEL NA TABELA EMPDATA
print(beer_user)
# Out:
# CORONA EXTRA

# %%
from sklearn.cluster import KMeans
import numpy as np

#importando base de dados
df = pd.read_csv("MLiHops.csv")
df
# Out:
#                 subrand   ibu  abv (%)  corpo  aroma  tipo  Unnamed: 6
# 0       BIRRA DEL BORGO  20.0      5.0      1      0    40           0
# 1                   BUD  10.0      5.0      0      0     2           0
# 2          CAMDEN HELLS  29.0      4.6      0      0     2           0
# 3       CAMDEN PALE ALE  39.0      4.0      1      5    40          25
# 4          CORONA EXTRA  18.0      4.6      0      0     2           0
# 5       GINETTE BLANCHE  12.0      5.0      0      0    41           0
# 6        GINETTE BLONDE  29.0      5.0      2      0    40           0
# 7         GINETTE FRUIT  12.0      4.0      1      5    20          25
# 8         GINETTE LAGER  25.0      4.5      0      0     2           0
# 9        GINETTE TRIPLE  15.0      9.0      1     10    44          50
# 10                GOOSE  55.0      5.9      1      5    45          25
# 11  HOEGARDEN GRAND CRU  35.0      8.5      1      5    46          25
# 12       HOEGARDEN ROSE   5.0      3.0      2      5    20          25
# 13      HOEGARDEN WHITE  15.0      4.9      0      5    41          25
# 14                 KWAK  16.0      8.4      2      5    46          25
# 15         LEFFE AMBREE  25.0      6.6      1     15    40          75
# 16        LEFFE BLONDE   21.5      6.6      0     15    42          75
# 17     LEFFE BLONDE 0,0  10.0      0.0      0     10    42          50
# 18          LEFFE BRUNE  20.0      6.5      0     15    43          75
# 19      LEFFE LA LEGERE  17.0      5.0      0     15     2          75
# 20       LEFFE RITUEL 9  25.0      9.0      2     15    46          75
# 21         LEFFE ROYALE  33.0      7.5      1      5    42          25
# 22           LEFFE RUBY  10.0      5.0      0      5    20          25
# 23         LEFFE TRIPLE  15.0      8.5      1      5    44          25
# 24     TRIPLE KARMELIET  31.0      8.4      1     15    44          75

# %%
array1 = []

#checar todas as ro
dicRecomendacao = {

  "Harmonizacao": {
  2 : "AMERICAN PALE ALE - Carnes grelhadas e saladas cítricas",
  40: "PALE LAGER - Hamburger, carnes vermelha e petiscos",
  43: "BROWN ALE - Carnes e petiscos",
  41: "WITBIER - Saladas, frutas do mar e comidas leves",
  44: "TRIPEL - Massas e frutos do mar",
  42: "BLONDE - Petiscos e frutos do mar",
  45: "STRONG - Frutos do mar e massas",
  46: "INDIAN PALE ALE - Queijo, carne vermelha, hamburger e petiscos",
  20: "FRUIT BEER - Sobremesa",
  },
  "Temperatura": {
  2: [8, 12],
  40: [0, 4],
  43: [8, 12],
  41: [4, 7],
  44: [4, 7],
  42: [2, 5],
  45: [10, 12],
  46: [8, 12],
  20: [7, 10],
  }
}

for i in range(25):  #itera sobre os valores e adiciona na lista array1

    temp = []
    temp.clear()

    p1 = df.iloc[i]['ibu']
    temp.append(p1)
    p2 = df.iloc[i]['abv (%)']
    temp.append(p2)
    p3 = df.iloc[i]['corpo']
    temp.append(p3)
    p4 = df.iloc[i]['aroma']
    temp.append(p4)
    p5 = df.iloc[i]['tipo']
    temp.append(p5)
    #p6 = dp.iloc[]["preco"]
    #temp.append(p6)

    array1.append(temp)

X = np.array(array1) #transforma a lista array1 em numpy

print(array1)
# Out:
# [[20.0, 5.0, 1, 0, 40], [10.0, 5.0, 0, 0, 2], [29.0, 4.6, 0, 0, 2], [39.0, 4.0, 1, 5, 40], [18.0, 4.6, 0, 0, 2], [12.0, 5.0, 0, 0, 41], [29.0, 5.0, 2, 0, 40], [12.0, 4.0, 1, 5, 20], [25.0, 4.5, 0, 0, 2], [15.0, 9.0, 1, 10, 44], [55.0, 5.9, 1, 5, 45], [35.0, 8.5, 1, 5, 46], [5.0, 3.0, 2, 5, 20], [15.0, 4.9, 0, 5, 41], [16.0, 8.4, 2, 5, 46], [25.0, 6.6, 1, 15, 40], [21.5, 6.6, 0, 15, 42], [10.0, 0.0, 0, 10, 42], [20.0, 6.5, 0, 15, 43], [17.0, 5.0, 0, 15, 2], [25.0, 9.0, 2, 15, 46], [33.0, 7.5, 1, 5, 42], [10.0, 5.0, 0, 5, 20], [15.0, 8.5, 1, 5, 44], [31.0, 8.4, 1, 15, 44]]

# %%
kmeans = KMeans(n_clusters=9, random_state=0).fit(X)
#pega todas a variaveis e as coloca em 10 grupos (mais parecidas)
tips = kmeans.labels_
print(tips)
# Out:
# [1 6 2 4 6 1 4 3 2 1 0 4 3 1 1 5 5 8 5 7 5 4 3 1 5]

# %%
import decimal 

def busca(array,beer):
    for i,el in enumerate(array):
        if el==beer:
            return i
    return None

def arrendondar (x):
    return int(decimal.Decimal(x).quantize(0, decimal.ROUND_HALF_UP))

def sum_array(array):
  if len(array)==0:
    return None
  soma = 0
  for i in array:
    soma += i
  return(soma/len(array))
################################################################################
def DataPreco(data, cerveja,conteiner,filtered_df,contador,quantidade_recomendada):
  mes = data[3:5]
  ano = data[6:]
  dia = data[:2]
  mes_atual = mes
  ano_atual = str(int(ano) - 1)
  dia_atual = dia
  dia30 = [4, 6, 9, 11]
  quantidade_container = 0





  
  filtered_df = filtered_df.loc[(filtered_df['Doc. Date'] >= f'{dia_atual}/{mes_atual}/{ano_atual}') & (filtered_df['Doc. Date'] < f'{dia_atual}/{mes_atual}/{ano}')]
  filtered_df.sort_values(by=['Doc. Date'], inplace = True, ascending = False)
    
  filtered_df = filtered_df.loc[filtered_df['Unidade Container']==conteiner]

  litros = filtered_df.iloc[0]['Container Size 2']
  #print(conteiner)
  #print(filtered_df.head())
  data_array = filtered_df['Preço/L'].to_numpy()
  media = sum_array(data_array)
  if media != None:
      #print("{1 CAIXA COM %d UNID E %.2f LITROS\npreco medio do L : %.2f"%(conteiner,litros,media))
      #print("1 CAIXA saira por %.2f $ (media * litragem da caixa)\
      #\ncolocar na parte de baixo de uma maneira mais organizada}"%(litros * media))
      if contador == 0:
          print("Recomendamos que voce compre %.2f litros dessa cervaja:"%(quantidade_recomendada))
      
      quantidade_container = arrendondar(quantidade_recomendada/litros)
      print("%d) %d container de %.2f L com %d unidades, com preco media do Litro de %.2f\nDando um total de %.2f $"
            %((contador+1),quantidade_container,litros,conteiner,media,litros * media))
  return 

def funcao(data, cerveja,quantidade_recomendada):
    #fazer lista com os tipos de conteiner da cerveja 
    filtered_df = empdata.loc[empdata["Subrand"] == cerveja]
    #print(filtered_df)
    array_available_conteiners = filtered_df['Unidade Container'].unique()
    
    #print(array_available_conteiners[0])
    num_conteiner = filtered_df['Unidade Container'].nunique()
    c = 0
    conteiner = 0
    while c<num_conteiner:
        DataPreco(data, cerveja,array_available_conteiners[c], filtered_df,c,quantidade_recomendada)
        c+=1
    
    #print("\nRecomendamos que voce compre T litros dessa cervaja:\n1) Y container de X\nDando um total de W $")
    #if True:
     #   print("2) YY container de XX\nDando um total de WW $")
    # preco_medio = 0
    return

# %%
#############################################################################
beer_array = df['subrand'].to_numpy()
tipo_array = df["tipo"].to_numpy()
Y = busca(beer_array, beer_user)
#print(Y)
qlqr = array1[Y]
a = kmeans.predict([qlqr])
#print(a)
var = np.where(tips == a)
#print("\n")
#saida da cerveja
bc = ""
cerveja_escolhida = []
print_out = ""
saida = False
dia_atual = "31/01/2021"
#Ultimo dia da tabela
print("------------------------------------------------------------------")
for i in (var):
  for ele in range(len(i)):
    bc = beer_array[i[ele]]
    var_a = i
    var_b = ele
    if bc != beer_user:
      saida = True
      cerveja_escolhida.append(bc)
      ad = i[ele]
      tipo_real = tipo_array[ad]
      #print(tipo_real)
      print("A cerveja recomendada é: ", bc)
      print_out = dicRecomendacao["Harmonizacao"][tipo_real]
      print(print_out)
      print_out = dicRecomendacao["Temperatura"][tipo_real]
      print("A temperatura ideal é entre: %d°C e %d°C\n" %(print_out[0],print_out[1]))
      #print(ad)
      #PRECISA LEVAR EM CONSIDERACAO OS DIFERENTES CONTEINERS -> TEM PRECOS DIFERENTES
      funcao(dia_atual, bc,quantidade_recomendada)
      print("------------------------------------------------------------------")
    

if saida == False:
  print("Nao temos recomendacao")
  print("------------------------------------------------------------------")
# Out:
# ------------------------------------------------------------------
# A cerveja recomendada é:  BUD
# AMERICAN PALE ALE - Carnes grelhadas e saladas cítricas
# A temperatura ideal é entre: 8°C e 12°C
#
# Recomendamos que voce compre 42.00 litros dessa cervaja:
# 1) 7 container de 6.00 L com 1 unidades, com preco media do Litro de 2.66
# Dando um total de 15.97 $
# 2) 5 container de 7.92 L com 24 unidades, com preco media do Litro de 3.00
# Dando um total de 23.78 $
# ------------------------------------------------------------------
# <ipython-input-212-6fb90ff680b6>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.sort_values(by=['Doc. Date'], inplace = True, ascending = False)
# <ipython-input-212-6fb90ff680b6>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.sort_values(by=['Doc. Date'], inplace = True, ascending = False)
